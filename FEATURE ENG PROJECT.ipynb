# %% [markdown]
# # Feature Engineering Project

# %% [markdown]
# ### 1. Feature Transforamtion

# %%
pip install -U numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/vamsi/Downloads/customer.csv")
df
# Out:
#       Unnamed: 0 Customer       State  CustomerLifetimeValue Response  \
# 0              0  BU79786  Washington            2763.519279       No
# 1              1  QZ44356     Arizona            6979.535903       No
# 2              2  AI49188      Nevada           12887.431650       No
# 3              3  WW63253  California            7645.861827       No
# 4              4  HB64268  Washington            2813.692575       No
# ...          ...      ...         ...                    ...      ...
# 9129        9129  LA72316  California           23405.987980       No
# 9130        9130  PK87824  California            3096.511217      Yes
# 9131        9131  TD14365  California            8163.890428       No
# 9132        9132  UP19263  California            7524.442436       No
# 9133        9133  Y167826  California            2611.836866       No
#
#       Coverage Education EffectiveToDate EmploymentStatus Gender  ...  \
# ...

# %%
df = df.drop(columns =['Unnamed: 0'])
df
# Out:
#      Customer       State  CustomerLifetimeValue Response  Coverage Education  \
# 0     BU79786  Washington            2763.519279       No     Basic  Bachelor
# 1     QZ44356     Arizona            6979.535903       No  Extended  Bachelor
# 2     AI49188      Nevada           12887.431650       No   Premium  Bachelor
# 3     WW63253  California            7645.861827       No     Basic  Bachelor
# 4     HB64268  Washington            2813.692575       No     Basic  Bachelor
# ...       ...         ...                    ...      ...       ...       ...
# 9129  LA72316  California           23405.987980       No     Basic  Bachelor
# 9130  PK87824  California            3096.511217      Yes  Extended   College
# 9131  TD14365  California            8163.890428       No  Extended  Bachelor
# 9132  UP19263  California            7524.442436       No  Extended   College
# 9133  Y167826  California            2611.836866       No  Extended   College
#
# ...

# %%
df.Customer	.unique()
# Out:
# array(['BU79786', 'QZ44356', 'AI49188', ..., 'TD14365', 'UP19263',
#        'Y167826'], shape=(9134,), dtype=object)

# %%
df.State.unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#       dtype=object)

# %%
df.CustomerLifetimeValue.unique()
# Out:
# array([ 2763.519279,  6979.535903, 12887.43165 , ...,  8163.890428,
#         7524.442436,  2611.836866], shape=(8041,))

# %%
df.Response.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.Coverage.unique()
# Out:
# array(['Basic', 'Extended', 'Premium'], dtype=object)

# %%
df.Education.unique()
# Out:
# array(['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor'],
#       dtype=object)

# %%
df.EffectiveToDate.unique()
# Out:
# array(['2/24/11', '1/31/11', '2/19/11', '1/20/11', '2/3/11', '1/25/11',
#        '1/18/11', '1/26/11', '2/17/11', '2/21/11', '1/6/11', '2/6/11',
#        '1/10/11', '1/17/11', '1/5/11', '2/27/11', '1/14/11', '1/21/11',
#        '2/5/11', '1/29/11', '2/28/11', '2/12/11', '2/2/11', '2/7/11',
#        '1/22/11', '2/13/11', '1/15/11', '1/8/11', '1/11/11', '1/28/11',
#        '2/8/11', '2/23/11', '1/2/11', '2/16/11', '1/27/11', '1/23/11',
#        '1/9/11', '2/11/11', '2/4/11', '2/1/11', '2/15/11', '2/26/11',
#        '1/16/11', '1/1/11', '2/10/11', '1/24/11', '2/25/11', '1/12/11',
#        '2/9/11', '1/19/11', '1/4/11', '2/14/11', '2/20/11', '2/18/11',
#        '1/3/11', '1/13/11', '1/30/11', '2/22/11', '1/7/11'], dtype=object)

# %%
df.EmploymentStatus.unique()
# Out:
# array(['Employed', 'Unemployed', 'Medical Leave', 'Disabled', 'Retired'],
#       dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.MonthsSincePolicyInception.unique()
# Out:
# array([ 5, 42, 38, 65, 44, 94, 13, 68,  3,  7, 87, 82, 25, 10, 50, 59,  1,
#        21, 49, 91, 47, 64, 54,  6, 14, 56, 17, 40, 62, 86, 79, 15, 32, 28,
#        16,  4, 57, 77, 95, 26, 53, 12, 98, 36, 71, 60, 20,  0, 27, 48, 33,
#        83, 30, 69, 90, 81, 84, 88, 18, 11, 85, 93, 34, 89,  2, 70, 37, 43,
#         8, 35, 99, 55, 75, 51, 92, 29, 63, 61, 46, 41, 31, 45, 67, 22, 23,
#         9, 72, 96, 58, 66, 73, 39, 19, 97, 52, 76, 78, 80, 74, 24])

# %%
df.NumberofOpenComplaints.unique()
# Out:
# array([0, 2, 1, 3, 5, 4])

# %%
df.NumberofPolicies.unique()
# Out:
# array([1, 8, 2, 7, 9, 4, 3, 6, 5])

# %%
df.PolicyType.unique()
# Out:
# array(['Corporate Auto', 'Personal Auto', 'Special Auto'], dtype=object)

# %%
df.RenewOfferType.unique()
# Out:
# array(['Offer1', 'Offer3', 'Offer2', 'Offer4'], dtype=object)

# %%
df.SalesChannel.unique()
# Out:
# array(['Agent', 'Call Center', 'Web', 'Branch'], dtype=object)

# %%
df.ClaimAmount.unique()
# Out:
# array([ 384.811147, 1131.464935,  566.472247, ...,  541.282007,
#         198.234764,  790.784983], shape=(5106,))

# %%
df.VehicleClass.unique()
# Out:
# array(['Two-Door Car', 'Four-Door Car', 'SUV', 'Luxury SUV', 'Sports Car',
#        'Luxury Car'], dtype=object)

# %%
df.VehicleSize.unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
df.describe()
# Out:
#        CustomerLifetimeValue        Income  MonthlyPremiumAuto  \
# count            9134.000000   9134.000000         9134.000000
# mean             8004.940475  37657.380009           93.219291
# std              6870.967608  30379.904734           34.407967
# min              1898.007675      0.000000           61.000000
# 25%              3994.251794      0.000000           68.000000
# 50%              5780.182197  33889.500000           83.000000
# 75%              8962.167041  62320.000000          109.000000
# max             83325.381190  99981.000000          298.000000
#
#        MonthsSinceLastClaim  MonthsSincePolicyInception  \
# count           9134.000000                 9134.000000
# mean              15.097000                   48.064594
# std               10.073257                   27.905991
# min                0.000000                    0.000000
# 25%                6.000000                   24.000000
# 50%               14.000000                   48.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer                    9134 non-null   object
#  1   State                       9134 non-null   object
#  2   CustomerLifetimeValue       9134 non-null   float64
#  3   Response                    9134 non-null   object
#  4   Coverage                    9134 non-null   object
#  5   Education                   9134 non-null   object
#  6   EffectiveToDate             9134 non-null   object
#  7   EmploymentStatus            9134 non-null   object
#  8   Gender                      9134 non-null   object
#  9   Income                      9134 non-null   int64
#  10  LocationCode                9134 non-null   object
#  11  MaritalStatus               9134 non-null   object
#  12  MonthlyPremiumAuto          9134 non-null   int64
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %%
df.dtypes
# Out:
# Customer                       object
# State                          object
# CustomerLifetimeValue         float64
# Response                       object
# Coverage                       object
# Education                      object
# EffectiveToDate                object
# EmploymentStatus               object
# Gender                         object
# Income                          int64
# LocationCode                   object
# MaritalStatus                  object
# MonthlyPremiumAuto              int64
# MonthsSinceLastClaim            int64
# MonthsSincePolicyInception      int64
# NumberofOpenComplaints          int64
# NumberofPolicies                int64
# PolicyType                     object
# Policy                         object
# RenewOfferType                 object
# SalesChannel                   object
# ClaimAmount                   float64
# VehicleClass                   object
# VehicleSize                    object
# dtype: object

# %%
df['Customer'] = df['Customer'].replace('...', np.nan)

# %%
df['Customer'].isnull().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9129    False
# 9130    False
# 9131    False
# 9132    False
# 9133    False
# Name: Customer, Length: 9134, dtype: bool>

# %%
df.Customer.unique()
# Out:
# array(['BU79786', 'QZ44356', 'AI49188', ..., 'TD14365', 'UP19263',
#        'Y167826'], shape=(9134,), dtype=object)

# %%
df['Customer'] = df.Customer.str.strip()

# %%
df['Customer'] = df.Customer.replace(' ...', np.nan)

# %%
df.Customer.unique()
# Out:
# array(['BU79786', 'QZ44356', 'AI49188', ..., 'TD14365', 'UP19263',
#        'Y167826'], shape=(9134,), dtype=object)

# %% [markdown]
# ## 1.1 FEATURE ENCODING
# ### LABEL ENCODING

# %%
# task-1 create a new column with integer values assigned to workclass categories

encoder = LabelEncoder() # Creating an label encoder object

encoder.fit(df['Customer']) # Assigning the numerical value to categorical variable (internally)

df['Customer'] = encoder.transform(df['Customer']) # Actually assigning numbers

display(df)
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington            2763.519279       No     Basic
# 1         5946     Arizona            6979.535903       No  Extended
# 2           96      Nevada           12887.431650       No   Premium
# 3         8016  California            7645.861827       No     Basic
# 4         2488  Washington            2813.692575       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California           23405.987980       No     Basic
# 9130      5390  California            3096.511217      Yes  Extended
# 9131      6688  California            8163.890428       No  Extended
# 9132      7214  California            7524.442436       No  Extended
# 9133      8434  California            2611.836866       No  Extended
#
#      Education EffectiveToDate EmploymentStatus Gender  Income  ...  \
# 0     Bachelor         2/24/11         Employed      F   56274  ...
# ...

# %%
encoder.classes_ # the sequences which the numbers are assigned
# Out:
# array(['AA10041', 'AA11235', 'AA16582', ..., 'ZZ89380', 'ZZ91716',
#        'ZZ97035'], shape=(9134,), dtype=object)

# %%
print(df.columns)
# Out:
# Index(['Customer', 'State', 'CustomerLifetimeValue', 'Response', 'Coverage',
#        'Education', 'EffectiveToDate', 'EmploymentStatus', 'Gender', 'Income',
#        'LocationCode', 'MaritalStatus', 'MonthlyPremiumAuto',
#        'MonthsSinceLastClaim', 'MonthsSincePolicyInception',
#        'NumberofOpenComplaints', 'NumberofPolicies', 'PolicyType', 'Policy',
#        'RenewOfferType', 'SalesChannel', 'ClaimAmount', 'VehicleClass',
#        'VehicleSize'],
#       dtype='object')

# %% [markdown]
# ## 2.Ordinal encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df.Education.unique()
# Out:
# array(['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor'],
#       dtype=object)

# %%
df['Education'] = df.Education.str.strip()

# %%
eduation_categories = ['High School or Below', 'College','Bachelor','Master', 'Doctor']

# %%
encoder = OrdinalEncoder(categories = [eduation_categories])

df['Education'] = encoder.fit_transform(df[['Education']])

df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington            2763.519279       No     Basic
# 1         5946     Arizona            6979.535903       No  Extended
# 2           96      Nevada           12887.431650       No   Premium
# 3         8016  California            7645.861827       No     Basic
# 4         2488  Washington            2813.692575       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California           23405.987980       No     Basic
# 9130      5390  California            3096.511217      Yes  Extended
# 9131      6688  California            8163.890428       No  Extended
# 9132      7214  California            7524.442436       No  Extended
# 9133      8434  California            2611.836866       No  Extended
#
#       Education EffectiveToDate EmploymentStatus Gender  Income  ...  \
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %% [markdown]
# ### 3.One Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

obj = OneHotEncoder(sparse_output = False, dtype = int)

new_col = obj.fit_transform(df[['Gender']])

print(type(new_col))
# Out:
# <class 'numpy.ndarray'>

# %%
encoded_df=pd.DataFrame(new_col,columns= obj.get_feature_names_out(['Gender']))
encoded_df
# Out:
#       Gender_F  Gender_M
# 0            1         0
# 1            1         0
# 2            1         0
# 3            0         1
# 4            0         1
# ...        ...       ...
# 9129         0         1
# 9130         1         0
# 9131         0         1
# 9132         0         1
# 9133         0         1
#
# [9134 rows x 2 columns]

# %%
df=pd.concat([df,encoded_df],axis=1)
df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington            2763.519279       No     Basic
# 1         5946     Arizona            6979.535903       No  Extended
# 2           96      Nevada           12887.431650       No   Premium
# 3         8016  California            7645.861827       No     Basic
# 4         2488  Washington            2813.692575       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California           23405.987980       No     Basic
# 9130      5390  California            3096.511217      Yes  Extended
# 9131      6688  California            8163.890428       No  Extended
# 9132      7214  California            7524.442436       No  Extended
# 9133      8434  California            2611.836866       No  Extended
#
#       Education EffectiveToDate EmploymentStatus Gender  Income  ...  \
# ...

# %%
df=df.drop('Gender',axis=1)
df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington            2763.519279       No     Basic
# 1         5946     Arizona            6979.535903       No  Extended
# 2           96      Nevada           12887.431650       No   Premium
# 3         8016  California            7645.861827       No     Basic
# 4         2488  Washington            2813.692575       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California           23405.987980       No     Basic
# 9130      5390  California            3096.511217      Yes  Extended
# 9131      6688  California            8163.890428       No  Extended
# 9132      7214  California            7524.442436       No  Extended
# 9133      8434  California            2611.836866       No  Extended
#
#       Education EffectiveToDate EmploymentStatus  Income LocationCode  ...  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

obj = OneHotEncoder(sparse_output = False, dtype = int)

new_col = obj.fit_transform(df[['MaritalStatus']])

print(type(new_col))
# Out:
# <class 'numpy.ndarray'>

# %%
encoded_df=pd.DataFrame(new_col,columns= obj.get_feature_names_out(['MaritalStatus']))
encoded_df
# Out:
#       MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single
# 0                          0                      1                     0
# 1                          0                      0                     1
# 2                          0                      1                     0
# 3                          0                      1                     0
# 4                          0                      0                     1
# ...                      ...                    ...                   ...
# 9129                       0                      1                     0
# 9130                       1                      0                     0
# 9131                       0                      0                     1
# 9132                       0                      1                     0
# 9133                       0                      0                     1
#
# [9134 rows x 3 columns]

# %%
df=pd.concat([df,encoded_df],axis=1)
df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington            2763.519279       No     Basic
# 1         5946     Arizona            6979.535903       No  Extended
# 2           96      Nevada           12887.431650       No   Premium
# 3         8016  California            7645.861827       No     Basic
# 4         2488  Washington            2813.692575       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California           23405.987980       No     Basic
# 9130      5390  California            3096.511217      Yes  Extended
# 9131      6688  California            8163.890428       No  Extended
# 9132      7214  California            7524.442436       No  Extended
# 9133      8434  California            2611.836866       No  Extended
#
#       Education EffectiveToDate EmploymentStatus  Income LocationCode  ...  \
# ...

# %%
df=df.drop('MaritalStatus',axis=1)
df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington            2763.519279       No     Basic
# 1         5946     Arizona            6979.535903       No  Extended
# 2           96      Nevada           12887.431650       No   Premium
# 3         8016  California            7645.861827       No     Basic
# 4         2488  Washington            2813.692575       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California           23405.987980       No     Basic
# 9130      5390  California            3096.511217      Yes  Extended
# 9131      6688  California            8163.890428       No  Extended
# 9132      7214  California            7524.442436       No  Extended
# 9133      8434  California            2611.836866       No  Extended
#
#       Education EffectiveToDate EmploymentStatus  Income LocationCode  ...  \
# ...

# %% [markdown]
# # Feature scaling
# ## MIN-MAX SCALER

# %%
from sklearn.preprocessing import MinMaxScaler
obj=MinMaxScaler()
df['CustomerLifetimeValue']=obj.fit_transform(df[['CustomerLifetimeValue']])
df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington               0.010629       No     Basic
# 1         5946     Arizona               0.062406       No  Extended
# 2           96      Nevada               0.134960       No   Premium
# 3         8016  California               0.070589       No     Basic
# 4         2488  Washington               0.011245       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California               0.264137       No     Basic
# 9130      5390  California               0.014719      Yes  Extended
# 9131      6688  California               0.076951       No  Extended
# 9132      7214  California               0.069098       No  Extended
# 9133      8434  California               0.008766       No  Extended
#
#       Education EffectiveToDate EmploymentStatus  Income LocationCode  ...  \
# ...

# %% [markdown]
# ## Standardization(Z-Score scaling)

# %%
from sklearn.preprocessing import StandardScaler
obj=StandardScaler()
df['ClaimAmount']=obj.fit_transform(df[['ClaimAmount']])
df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0          600  Washington               0.010629       No     Basic
# 1         5946     Arizona               0.062406       No  Extended
# 2           96      Nevada               0.134960       No   Premium
# 3         8016  California               0.070589       No     Basic
# 4         2488  Washington               0.011245       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129      3857  California               0.264137       No     Basic
# 9130      5390  California               0.014719      Yes  Extended
# 9131      6688  California               0.076951       No  Extended
# 9132      7214  California               0.069098       No  Extended
# 9133      8434  California               0.008766       No  Extended
#
#       Education EffectiveToDate EmploymentStatus  Income LocationCode  ...  \
# ...

# %% [markdown]
# ## Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
obj=RobustScaler()
df['Customer']=obj.fit_transform(df[['Customer']])
df
# Out:
#       Customer       State  CustomerLifetimeValue Response  Coverage  \
# 0    -0.868608  Washington               0.010629       No     Basic
# 1     0.302091     Arizona               0.062406       No  Extended
# 2    -0.978977      Nevada               0.134960       No   Premium
# 3     0.755393  California               0.070589       No     Basic
# 4    -0.455163  Washington               0.011245       No     Basic
# ...        ...         ...                    ...      ...       ...
# 9129 -0.155371  California               0.264137       No     Basic
# 9130  0.180335  California               0.014719      Yes  Extended
# 9131  0.464579  California               0.076951       No  Extended
# 9132  0.579766  California               0.069098       No  Extended
# 9133  0.846929  California               0.008766       No  Extended
#
#       Education EffectiveToDate EmploymentStatus  Income LocationCode  ...  \
# ...

# %%
encoder = LabelEncoder() # Creating an label encoder object
columns=['State','Response','Coverage','EffectiveToDate','EmploymentStatus','LocationCode','PolicyType','Policy','RenewOfferType','SalesChannel','VehicleClass','VehicleSize']  
for col_name in columns:
        df[col_name] = encoder.fit_transform(df[col_name]) # Actually assigning numbers
display(df)
# Out:
#       Customer  State  CustomerLifetimeValue  Response  Coverage  Education  \
# 0    -0.868608      4               0.010629         0         0        2.0
# 1     0.302091      0               0.062406         0         1        2.0
# 2    -0.978977      2               0.134960         0         2        2.0
# 3     0.755393      1               0.070589         0         0        2.0
# 4    -0.455163      4               0.011245         0         0        2.0
# ...        ...    ...                    ...       ...       ...        ...
# 9129 -0.155371      1               0.264137         0         0        2.0
# 9130  0.180335      1               0.014719         1         1        1.0
# 9131  0.464579      1               0.076951         0         1        2.0
# 9132  0.579766      1               0.069098         0         1        1.0
# 9133  0.846929      1               0.008766         0         1        1.0
#
# ...

# %% [markdown]
# ### Do Feature scaling for all columns (Min-Max)

# %%
from sklearn.preprocessing import MinMaxScaler
obj=MinMaxScaler(feature_range=(0,1))
columns=['State','Customer','ClaimAmount','Response','Coverage','Education','Income','NumberofPolicies','EffectiveToDate','EmploymentStatus','LocationCode','PolicyType','Policy','RenewOfferType','SalesChannel','VehicleClass','VehicleSize']  
for col_name in columns:
        df[col_name] = obj.fit_transform(df[[col_name]]) # Actually assigning numbers
df
# Out:
#       Customer  State  CustomerLifetimeValue  Response  Coverage  Education  \
# 0     0.065696   1.00               0.010629       0.0       0.0       0.50
# 1     0.651046   0.00               0.062406       0.0       0.5       0.50
# 2     0.010511   0.50               0.134960       0.0       1.0       0.50
# 3     0.877696   0.25               0.070589       0.0       0.0       0.50
# 4     0.272419   1.00               0.011245       0.0       0.0       0.50
# ...        ...    ...                    ...       ...       ...        ...
# 9129  0.422315   0.25               0.264137       0.0       0.0       0.50
# 9130  0.590168   0.25               0.014719       1.0       0.5       0.25
# 9131  0.732289   0.25               0.076951       0.0       0.5       0.50
# 9132  0.789883   0.25               0.069098       0.0       0.5       0.25
# 9133  0.923464   0.25               0.008766       0.0       0.5       0.25
#
# ...

# %%
df.select_dtypes(include="object").columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# # 2.Feature Selection

# %% [markdown]
# ### Correlation Matrix

# %%
corr=df.corr()

# %%
corr
# Out:
#                             Customer     State  CustomerLifetimeValue  \
# Customer                    1.000000  0.011494              -0.028605
# State                       0.011494  1.000000               0.008778
# CustomerLifetimeValue      -0.028605  0.008778               1.000000
# Response                    0.023256 -0.002473              -0.008930
# Coverage                   -0.005677  0.002047               0.168040
# Education                  -0.005979 -0.003758              -0.018772
# EffectiveToDate            -0.003460 -0.002864              -0.012978
# EmploymentStatus            0.010265  0.000368              -0.034846
# Income                     -0.008700  0.004620               0.024366
# LocationCode                0.016476 -0.005240               0.004854
# MonthlyPremiumAuto          0.002520  0.007898               0.396262
# MonthsSinceLastClaim        0.012043  0.002126               0.011517
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr,annot=True,fmt='.2f')#cmap='coolwarm',
plt.show()

# %%
high_corr=corr.unstack()
print(high_corr)
# Out:
# Customer              Customer                  1.000000
#                       State                     0.011494
#                       CustomerLifetimeValue    -0.028605
#                       Response                  0.023256
#                       Coverage                 -0.005677
#                                                   ...
# MaritalStatus_Single  Gender_F                 -0.043444
#                       Gender_M                  0.043444
#                       MaritalStatus_Divorced   -0.255417
#                       MaritalStatus_Married    -0.714885
#                       MaritalStatus_Single      1.000000
# Length: 729, dtype: float64

# %%
high_corr=corr.unstack().reset_index()
print(high_corr)
# Out:
#                   level_0                 level_1         0
# 0                Customer                Customer  1.000000
# 1                Customer                   State  0.011494
# 2                Customer   CustomerLifetimeValue -0.028605
# 3                Customer                Response  0.023256
# 4                Customer                Coverage -0.005677
# ..                    ...                     ...       ...
# 724  MaritalStatus_Single                Gender_F -0.043444
# 725  MaritalStatus_Single                Gender_M  0.043444
# 726  MaritalStatus_Single  MaritalStatus_Divorced -0.255417
# 727  MaritalStatus_Single   MaritalStatus_Married -0.714885
# 728  MaritalStatus_Single    MaritalStatus_Single  1.000000
#
# [729 rows x 3 columns]

# %%
high_corr.columns=['Feature1','Feature2','Correlation']

# %%
print(high_corr)
# Out:
#                  Feature1                Feature2  Correlation
# 0                Customer                Customer     1.000000
# 1                Customer                   State     0.011494
# 2                Customer   CustomerLifetimeValue    -0.028605
# 3                Customer                Response     0.023256
# 4                Customer                Coverage    -0.005677
# ..                    ...                     ...          ...
# 724  MaritalStatus_Single                Gender_F    -0.043444
# 725  MaritalStatus_Single                Gender_M     0.043444
# 726  MaritalStatus_Single  MaritalStatus_Divorced    -0.255417
# 727  MaritalStatus_Single   MaritalStatus_Married    -0.714885
# 728  MaritalStatus_Single    MaritalStatus_Single     1.000000
#
# [729 rows x 3 columns]

# %%
high_corr=high_corr[(high_corr['Correlation']>0.3)&(high_corr['Correlation'] !=1)]

# %%
high_corr=high_corr.sort_values(by="Correlation",ascending=True)

# %%
high_corr
# Out:
#                   Feature1               Feature2  Correlation
# 208       EmploymentStatus            ClaimAmount     0.330465
# 520            ClaimAmount       EmploymentStatus     0.330465
# 709   MaritalStatus_Single       EmploymentStatus     0.386769
# 215       EmploymentStatus   MaritalStatus_Single     0.386769
# 64   CustomerLifetimeValue     MonthlyPremiumAuto     0.396262
# 272     MonthlyPremiumAuto  CustomerLifetimeValue     0.396262
# 118               Coverage     MonthlyPremiumAuto     0.458997
# 274     MonthlyPremiumAuto               Coverage     0.458997
# 523            ClaimAmount     MonthlyPremiumAuto     0.632017
# 289     MonthlyPremiumAuto            ClaimAmount     0.632017
# 421             PolicyType                 Policy     0.879964
# 447                 Policy             PolicyType     0.879964

# %% [markdown]
# ## ChiSquare test

# %% [markdown]
# ### It is used to find the relation between 2 "categorical" Variables

# %%
from scipy.stats import chi2_contingency

# %%
contingency_matrix = pd.crosstab(df['Education'], df['EmploymentStatus'])

# %%
contingency_matrix
# Out:
# EmploymentStatus  0.00  0.25  0.50  0.75  1.00
# Education
# 0.00               118  1528   115    72   789
# 0.25                98  1664   145   102   672
# 0.50               121  1702   126    88   711
# 0.75                46   555    29    19    92
# 1.00                22   249    17     1    53

# %%
#sns.pairplot(df,hue='EmploymentStatus')

# %%
sns.lineplot(x='EmploymentStatus',y='Education',data=df)
# Out:
# <Axes: xlabel='EmploymentStatus', ylabel='Education'>

# %%
### chi2_contingency() returns 4 values
### to not recevie values _ is placed bcz we cant skip it

# %%
_ , p_value, _ ,_ = chi2_contingency(contingency_matrix)

# %%
p_value
# Out:
# np.float64(1.3729369098070774e-23)

# %%
var1 , p_value, var2 ,var3 = chi2_contingency(contingency_matrix)

# %%
var1
# Out:
# np.float64(148.7577942228439)

# %%
var2
# Out:
# 16

# %%
var3
# Out:
# array([[ 116.25903219, 1635.66411211,  124.00963433,   80.95073352,
#          665.11648785],
#        [ 118.87508211, 1672.46967375,  126.80008758,   82.7722794 ,
#          680.08287716],
#        [ 121.84585067, 1714.26582001,  129.96890738,   84.84081454,
#          697.0786074 ],
#        [  32.85581344,  462.25290125,   35.04620101,   22.87738121,
#          187.96770309],
#        [  15.16422159,  213.34749288,   16.1751697 ,   10.55879133,
#           86.7543245 ]])

# %%
df.EmploymentStatus	.value_counts().plot(kind = 'pie', autopct = '%0.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 3.FEATURE BALANCING
# ## OVER SAMPLING

# %% [markdown]
# ## RandomOverSampler

# %% [markdown]
# ## Smote

# %%
get_ipython().system('pip install imbalanced-learn')

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
x = df.drop('EmploymentStatus', axis = 1)  
#entire dataset expect income column bcz we deleted and this updated data is stored in x

# %%
  y = df.loc[: , ['EmploymentStatus']]  
#income column with all the rows stored in y

# %%
### not majority - resample all the classes but the majority classes(expect majority class)

# %%
y.value_counts()
# Out:
# EmploymentStatus
# 0.25                5698
# 1.00                2317
# 0.50                 432
# 0.00                 405
# 0.75                 282
# Name: count, dtype: int64

# %%
obj_ros = RandomOverSampler(sampling_strategy = 'not majority')
y_int = y.astype(int)
x_ros, y_ros = obj_ros.fit_resample(x,y_int)

# %%
y_ros.value_counts() #After resampling
# Out:
# EmploymentStatus
# 0                   6817
# 1                   6817
# Name: count, dtype: int64

# %%
## SMOTE

# %%
### 50 % of miniority class is added here

# %%
obj_smote = SMOTE(sampling_strategy = .5)

x_smote, y_smote = obj_smote.fit_resample(x,y_int)

# %%
y_smote.value_counts()
# Out:
# EmploymentStatus
# 0                   6817
# 1                   3408
# Name: count, dtype: int64

# %% [markdown]
# # UnderSampling
# ## RandomUnderSampler
# ## EditedNearestNeighbours

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
obj_rus = RandomUnderSampler(sampling_strategy = 'not minority')
x_rus, y_rus = obj_rus.fit_resample(x,y_int)

# %%
y_rus.value_counts()
# Out:
# EmploymentStatus
# 0                   2317
# 1                   2317
# Name: count, dtype: int64

# %%
#EditedNearestNeighbours
from imblearn.under_sampling import EditedNearestNeighbours

# %%
obj_enn = EditedNearestNeighbours(n_neighbors = 5)
x_enn, y_enn = obj_enn.fit_resample(x,y_int)

# %%
y_enn.value_counts()
# Out:
# EmploymentStatus
# 0                   2575
# 1                   2317
# Name: count, dtype: int64
